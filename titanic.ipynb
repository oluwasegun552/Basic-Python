# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\HP ENVY\Downloads\Videos\titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_cleaned=df.dropna()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df_cleaned=df.dropna()
#
# NameError: name 'df' is not defined

# %% [markdown]
# ### passenger in first class, second class and third class.

# %%
def count_passenger_class(data):
    first_class = df[df['Pclass'] == 1]['Pclass'].count()
    second_class = df[df['Pclass'] == 2]['Pclass'].count()
    third_class = df[df['Pclass'] == 3]['Pclass'].count()
    return first_class, second_class, third_class

first_class, second_class, third_class = count_passenger_class(df)
print("Number of passengers in first class:", first_class)
print("Number of passengers in second class:", second_class)
print("Number of passengers in third class:", third_class)
# Out:
# Number of passengers in first class: 216
# Number of passengers in second class: 184
# Number of passengers in third class: 491
